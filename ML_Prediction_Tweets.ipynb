# %%
##Part 2:
##BUilding Logistic Regrssion Model building
##importing required libraries 
import pandas as pd
import sys
import csv
import time
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import json
from textblob import TextBlob
from pyspark import SparkContext
from pyspark.sql.session import SparkSession
from pyspark.streaming import StreamingContext
import pyspark.sql.types as tp
from pyspark.ml import Pipeline
from pyspark.ml.feature import StringIndexer, OneHotEncoderEstimator, VectorAssembler
from pyspark.ml.feature import StopWordsRemover, Word2Vec, RegexTokenizer
from pyspark.ml.classification import LogisticRegression
from pyspark.sql import Row
import datetime

# initializing spark session
sc = SparkContext.getOrCreate()
spark = SparkSession(sc)
    
# define the schema
my_schema = tp.StructType([
  tp.StructField(name= 'label',       dataType= tp.IntegerType(),  nullable= True),
  tp.StructField(name= 'id',          dataType= tp.IntegerType(),  nullable= True),
  tp.StructField(name= 'Day',       dataType= tp.StringType(),   nullable= True),
  tp.StructField(name= 'device',       dataType= tp.StringType(),   nullable= True),
  tp.StructField(name= 'user',       dataType= tp.StringType(),   nullable= True),
  tp.StructField(name= 'tweet',       dataType= tp.StringType(),   nullable= True)
])
    
# read the training dataset  
my_data = spark.read.csv('testdata.manual.2009.06.14.csv',
                         schema=my_schema,
                         header=True)

# view the data
my_data.show(5)

# print the schema of the file
my_data.printSchema()
# Out:
# +-----+---+--------------------+-------+------------+--------------------+
# |label| id|                 Day| device|        user|               tweet|
# +-----+---+--------------------+-------+------------+--------------------+
# |    4|  4|Mon May 11 03:18:...|kindle2|      vcu451|Reading my kindle...|
# |    4|  5|Mon May 11 03:18:...|kindle2|      chadfu|Ok, first assesme...|
# |    4|  6|Mon May 11 03:19:...|kindle2|       SIX15|@kenburbary You'l...|
# |    4|  7|Mon May 11 03:21:...|kindle2|    yamarama|@mikefish  Fair e...|
# |    4|  8|Mon May 11 03:22:...|kindle2|GeorgeVHulme|@richardebaker no...|
# +-----+---+--------------------+-------+------------+--------------------+
# only showing top 5 rows
#
# root
#  |-- label: integer (nullable = true)
#  |-- id: integer (nullable = true)
#  |-- Day: string (nullable = true)
#  |-- device: string (nullable = true)
#  |-- user: string (nullable = true)
#  |-- tweet: string (nullable = true)

# %%
#stage 1: tokenizing the tweet into tokens   
stage_1 = RegexTokenizer(inputCol= 'tweet' , outputCol= 'tokens', pattern= '\\W')
#stage 2: removing the stop words
stage_2 = StopWordsRemover(inputCol= 'tokens', outputCol= 'filtered_words')
#stage 3: creating the word vector of size 100
stage_3 = Word2Vec(inputCol= 'filtered_words', outputCol= 'vector', vectorSize= 100)
# define stage 4: Logistic Regression Model
model = LogisticRegression(featuresCol= 'vector', labelCol= 'label')

# %%
# setting up the pipeline
pipeline = Pipeline(stages= [stage_1, stage_2, stage_3, model])

# fit the pipeline model with the training data
pipelineFit = pipeline.fit(my_data)

# %%
# define a function to compute sentiments of the received tweets
import time
x_value=0
def get_prediction(tweet_text):
	try:
		global x_value   
		fieldnames = ["x_value","total_1","pospercent","neupercent"]

 # filter the tweets whose length is greater than 0
		tweet_text = tweet_text.filter(lambda x: len(x) > 0)
    # create a dataframe with column name 'tweet' and each row will contain the tweet
		rowRdd = tweet_text.map(lambda w: Row(tweet=w))
    # create a spark dataframe
		wordsDataFrame = spark.createDataFrame(rowRdd)
    # run the model using the pipeline and get the predicted value

		total=pipelineFit.transform(wordsDataFrame).select('tweet','prediction')
		negtweets=total.where(total['prediction']=='0.0').select('tweet','prediction')
		postweets=total.where(total['prediction']=='4.0').select('tweet','prediction')
		nuetraltweet=total.where(total['prediction']=='2.0').select('tweet','prediction')        
		percent=((negtweets.count()/total.count())*100)
		pospercent=((postweets.count()/total.count())*100)
		neupercent=((nuetraltweet.count()/total.count())*100)        
		print("Negative tweets percentage:%",percent)
		print("Positive tweets percentage:%",pospercent)
		print("Neutral tweets percentage:%",neupercent)        
		total.show()
    ##Writing the csv file with the % share of tweets from each fetch
		with open('percent.csv', 'a') as csv_file:
			csv_writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
			info = {
			"total_1": percent,
			"pospercent": pospercent,
			"neupercent": neupercent                    
			}
			csv_writer.writerow(info)

		time.sleep(1)

	except : 
		print('No data')
		e = sys.exc_info()[0]
		print("This Error: %s" % e)
    
# Initialize the streaming context 
ssc = StreamingContext(sc, batchDuration= 3)##Time interval of 3 seconds

# Creating the DStream which connects to hostname:port, like localhost:9099
lines = ssc.socketTextStream('localhost', 9099) ##ports to be noted before fetching tweets

# split the tweet text by a keyword 'TWEET_APP' so that we can identify which set of words is from a single tweet
words = lines.flatMap(lambda line : line.split('TWEET_APP'))

##Filter to seperate tweets for a Particular Store (Costco or Walmart)
words=words.filter(lambda s:'costco' in s)

##Calling the get_Prediction function to predict the sentiments 
words.foreachRDD(get_prediction)

# Start streaming
ssc.start()             

# Wait for the computation to terminate
ssc.awaitTermination()
# Out:
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @SusanLiTV: #C...|       0.0|
# |Concerns over a #...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 100.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Have fun in your ...|       2.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 100.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@Walmart Just hop...|       2.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 50.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 50.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |   a need not a want|       2.0|
# |RT @dodaistewart:...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 80.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 20.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @BardsOfWar: C...|       0.0|
# |              Masks.|       0.0|
# |  Social distancing.|       0.0|
# |     Food rationing.|       2.0|
# |    You are witness…|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @michellemalki...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 33.33333333333333
# Positive tweets percentage:% 33.33333333333333
# Neutral tweets percentage:% 33.33333333333333
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @SEDLAW15: Quo...|       4.0|
# |RT @TrumperSeaney...|       2.0|
# |Ever since the ou...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 40.0
# Positive tweets percentage:% 20.0
# Neutral tweets percentage:% 40.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# | RT @COsweda: Thread|       2.0|
# |      What a shame. |       0.0|
# |@Timcast went bac...|       2.0|
# |It looks like he'...|       0.0|
# |RT @SEDLAW15: Quo...|       4.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 75.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 25.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @V_actually: C...|       0.0|
# |Is this a ploy to...|       2.0|
# |Or a push for lab...|       0.0|
# |RT @KING5Seattle:...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@C36220977 Wake u...|       0.0|
# |Bro never again a...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @raknouk: @Mic...|       0.0|
# |       1) against T…|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'PermissionError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Why is there no s...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @B52Malmet: In...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @Gina4DJT2020:...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 50.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 50.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Hy-Vee's New Meat...|       2.0|
# |@takintime @LAWYE...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@TrumperSeaney @i...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 50.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 50.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@costco just canc...|       0.0|
# |Here I come. @sam...|       2.0|
# |I look forward to...|       2.0|
# |@_captainscience ...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 100.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |We made a pass by...|       4.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 75.0
# Positive tweets percentage:% 25.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @Sam2323_43433...|       0.0|
# |        🚧🚧🚧🚧🚧🚧|       0.0|
# |All, Employees An...|       0.0|
# |Costco and Kroger...|       4.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 66.66666666666666
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 33.33333333333333
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@gollywog1963 @su...|       0.0|
# |RT @TrumperSeaney...|       2.0|
# |Ever since the ou...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @B52Malmet: In...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 66.66666666666666
# Positive tweets percentage:% 33.33333333333333
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Is this suppose t...|       0.0|
# |Get real @NEWPOST...|       4.0|
# |RT @B52Malmet: In...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 66.66666666666666
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 33.33333333333333
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@IamTheBeard10 @T...|       0.0|
# |* You don’t think...|       0.0|
# |Nice approach at ...|       2.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |NOW @Costco IS "U...|       0.0|
# |FUCK THEM AND THE...|       0.0|
# |😡😡😡😡… https:/...|       0.0|
# |@TreadLightly_RE ...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 100.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@RedQueenCoder @a...|       4.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @NEWDAWN20202:...|       0.0|
# |FUCK THEM AND THE...|       0.0|
# |            😡😡😡😡|       0.0|
# |        #SELFSUSTAI…|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 50.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 50.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |I've just posted ...|       2.0|
# |@valerialaurette ...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 100.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @SEDLAW15: Quo...|       4.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 100.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @SEDLAW15: Quo...|       4.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@giselejohnston I...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @raknouk: @Mic...|       0.0|
# |       1) against T…|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 100.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @chigrl: #supp...|       2.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @Sam2323_43433...|       0.0|
# |        🚧🚧🚧🚧🚧🚧|       0.0|
# |All, Employees An...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Pure Earth sheets...|       0.0|
# |Save $8 on the Pu...|       0.0|
# |@BardsOfWar The a...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 100.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @nursekelsey: ...|       4.0|
# |Nothing like a Co...|       4.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |So meat packing p...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 100.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @JayleneMarie7...|       2.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Grocery chains li...|       0.0|
# |For the life of m...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @raknouk: @Mic...|       0.0|
# |       1) against T…|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@JamesWallerD Our...|       0.0|
# |#Costco is offici...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |#VIRUSHOAX AND @C...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @NEWDAWN20202:...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@intheMatrixxx Ju...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 66.66666666666666
# Positive tweets percentage:% 33.33333333333333
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @CKG1959: The ...|       0.0|
# |Amid pandemic, Al...|       0.0|
# |Haven’t been to C...|       4.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 50.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 50.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@AWeaverWrites We...|       2.0|
# |@PauletteParis1 @...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 100.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Someone let me us...|       4.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |bro what i wouldn...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 100.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @Oda_CM: I scr...|       2.0|
# |@0xEnder What if....|       2.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 100.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Apparently it’s b...|       4.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Amid pandemic, Al...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @Sam2323_43433...|       0.0|
# |        🚧🚧🚧🚧🚧🚧|       0.0|
# |All, Employees An...|       0.0|
# |@BardsOfWar @Bobb...|       0.0|
# |It's a rigged game. |       0.0|
# |Austin, TX said I...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 100.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Change my mind: K...|       2.0|
# |Just left my loca...|       2.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Just in:  @HyVee ...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @Pinkadoodlezz...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 100.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @sherilynch: a...|       2.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@takintime @LAWYE...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 100.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Costco says it wi...|       2.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 100.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Visa: "1/5 of US ...|       2.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 50.0
# Positive tweets percentage:% 50.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@M2Madness I was ...|       0.0|
# |RT @nursekelsey: ...|       4.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 100.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Ok stucky stan — ...|       2.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 100.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@SSG_PAIN @BardsO...|       2.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 50.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 50.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @TrumperSeaney...|       2.0|
# |Ever since the ou...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@CH_1875 @Holly_D...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 100.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@mat Going to Cos...|       4.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@briansdeely I'm ...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |As meat plants fa...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 66.66666666666666
# Positive tweets percentage:% 33.33333333333333
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |“You boys know th...|       4.0|
# |If you guys liste...|       0.0|
# |RT @dconcetta2860...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 50.0
# Positive tweets percentage:% 50.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |I want Costco coo...|       4.0|
# |I had a temp job ...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 100.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @SEDLAW15: Quo...|       4.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 88.88888888888889
# Positive tweets percentage:% 11.11111111111111
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |I DID NOT WRITE T...|       0.0|
# |Craig Jaeger’s post:|       0.0|
# |“I can’t. I just ...|       0.0|
# |     shop at Costco.|       0.0|
# |You are not the c...|       0.0|
# |           Nor am I.|       0.0|
# |Our supply chain ...|       0.0|
# |spouses who are m...|       0.0|
# |RT @SEDLAW15: Quo...|       4.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |You’re also requi...|       0.0|
# |Ask… https://t.co...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @emochanel1307...|       0.0|
# |RT @RL9631: @kidg...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 100.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @SEDLAW15: Quo...|       4.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Costco has limite...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 66.66666666666666
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 33.33333333333333
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @V_actually: C...|       0.0|
# |Is this a ploy to...|       2.0|
# |Or a push for lab...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 100.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |These fuckin Kare...|       2.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 66.66666666666666
# Positive tweets percentage:% 33.33333333333333
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Everyone in their...|       0.0|
# |An incidental run...|       4.0|
# |RT @urnerbarry: C...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 50.0
# Neutral tweets percentage:% 50.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @TheeDaddy: @K...|       4.0|
# |RT @BenKTallmadge...|       2.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @urnerbarry: C...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Last night I acci...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 33.33333333333333
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 66.66666666666666
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |What do you do wh...|       0.0|
# |Why, you memorial...|       2.0|
# |RT @WaterLynnn: O...|       2.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 100.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@SueBee0619 @AWea...|       4.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @urnerbarry: C...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @chessonhadley...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@onejoey Grabbing...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 50.0
# Positive tweets percentage:% 50.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |I’ve been correct...|       0.0|
# |RT @SEDLAW15: Quo...|       4.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 100.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |9 months preggo a...|       2.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 50.0
# Positive tweets percentage:% 50.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @Fearless45_MA...|       0.0|
# |@GovTimWalz We ar...|       4.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@MarcLHommedieu S...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @_David_Edward...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 100.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@giirlybabe I got...|       4.0|
# |RT @SEDLAW15: Quo...|       4.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 66.66666666666666
# Positive tweets percentage:% 16.666666666666664
# Neutral tweets percentage:% 16.666666666666664
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @BardsOfWar: C...|       0.0|
# |              Masks.|       0.0|
# |  Social distancing.|       0.0|
# |     Food rationing.|       2.0|
# |    You are witness…|       0.0|
# |RT @SEDLAW15: Quo...|       4.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @Ebontis: Last...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 100.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Baba and I went t...|       2.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 60.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 40.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# | RT @COsweda: Thread|       2.0|
# |      What a shame. |       0.0|
# |@Timcast went bac...|       2.0|
# |It looks like he'...|       0.0|
# |@mat Hitting Cost...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @Sam2323_43433...|       0.0|
# |        🚧🚧🚧🚧🚧🚧|       0.0|
# |All, Employees An...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 100.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Costco limits U.S...|       4.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |America IS BACK i...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@NewDay @CNN @Kyu...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@patton6966 I don...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 50.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 50.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@JessTheReaper @H...|       0.0|
# |im really tryna f...|       2.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 60.0
# Positive tweets percentage:% 20.0
# Neutral tweets percentage:% 20.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @policrits: Mu...|       2.0|
# |Asian (chinese?) ...|       0.0|
# |Governor's demand...|       0.0|
# |          Costco ra…|       0.0|
# |RT @SEDLAW15: Quo...|       4.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 50.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 50.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @TrumperSeaney...|       2.0|
# |Ever since the ou...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 50.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 50.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @TrumperSeaney...|       2.0|
# |Ever since the ou...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 100.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |I'm curious as to...|       2.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @emilia_suze: ...|       0.0|
# |RT @MichaelLibbie...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 100.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @HouseMusicTV:...|       2.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 50.0
# Positive tweets percentage:% 50.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@purpleweasel @jc...|       0.0|
# |I'm going to Cost...|       4.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @braidsxo: y’a...|       0.0|
# |For anyone buying...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Trip to @costco f...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 100.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Nothing lIke #Cos...|       4.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@Kturner_ne CostC...|       0.0|
# |RT @bustedcoverag...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@krismeetsworld T...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 100.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@BrandiKruse @EME...|       2.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |I will always fuc...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |This morning I ha...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Costco is a war zone|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Survived Costco! ...|       0.0|
# |RT @AllForLoveQ: ...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 66.66666666666666
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 33.33333333333333
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @V_actually: C...|       0.0|
# |Is this a ploy to...|       2.0|
# |Or a push for lab...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |2019 this guy is ...|       0.0|
# |2020 this guy is ...|       0.0|
# |                   .|       0.0|
# |Stay Pure my frie...|       0.0|
# |                   .|       0.0|
# |Det… https://t.co...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Facebook posts: W...|       0.0|
# |@noctour_ @SandiR...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 100.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @SEDLAW15: Quo...|       4.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 100.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @AirborneGeek:...|       2.0|
# |Oh--and I cannot ...|       2.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 100.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Good thing I don'...|       4.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 100.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@reallouiehuey Ju...|       2.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 66.66666666666666
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 33.33333333333333
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @TrumperSeaney...|       2.0|
# |Ever since the ou...|       0.0|
# |@2Puggy @SSG_PAIN...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@SelfDestructCap ...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 80.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 20.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @BardsOfWar: C...|       0.0|
# |              Masks.|       0.0|
# |  Social distancing.|       0.0|
# |     Food rationing.|       2.0|
# |    You are witness…|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@TomiLahren @real...|       0.0|
# |RT @Sam2323_43433...|       0.0|
# |        🚧🚧🚧🚧🚧🚧|       0.0|
# |All, Employees An...|       0.0|
# |RT @emilia_suze: ...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 33.33333333333333
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 66.66666666666666
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @GoldTelegraph...|       2.0|
# |Meat shortages be...|       0.0|
# |‣ Costco said tod...|       2.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 33.33333333333333
# Positive tweets percentage:% 66.66666666666666
# Neutral tweets percentage:% 0.0
# ...
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @TrumperSeaney...|       2.0|
# |Ever since the ou...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Because you’re no...|       0.0|
# |@vollinda @Walmar...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 50.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 50.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @MspdcaliKag: ...|       0.0|
# |We need to “Open ...|       2.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 100.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |The boys are way ...|       4.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 100.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@ItGetsNoBetter8 ...|       2.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 50.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 50.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @ForbesLorne: ...|       2.0|
# |#PopowichMeats #Y...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@PamelaGeller @Ox...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 100.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@takintime @Costc...|       2.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @emilia_suze: ...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 50.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 50.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |If I can’t go to ...|       0.0|
# |@JessLevo We have...|       2.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Costco Canada Now...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 33.33333333333333
# Positive tweets percentage:% 33.33333333333333
# Neutral tweets percentage:% 33.33333333333333
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@BENBALLER I boug...|       2.0|
# |RT @ImKingGinger:...|       4.0|
# |https://t.co/4QwZ...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@Bunkers4All Cost...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |girls with 20 bod...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 50.0
# Positive tweets percentage:% 50.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @chris_howell1...|       0.0|
# |@mtracey Welcome ...|       4.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 100.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |might demand my m...|       2.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@RinTohsaka710 gi...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 75.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 25.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@AskCiti Costco C...|       0.0|
# |@StillWilliamB @1...|       0.0|
# |Me and wife: Cost...|       0.0|
# |Libertarian Will:...|       2.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 66.66666666666666
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 33.33333333333333
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @V_actually: C...|       0.0|
# |Is this a ploy to...|       2.0|
# |Or a push for lab...|       0.0|
# |RT @V_actually: C...|       0.0|
# |Is this a ploy to...|       2.0|
# |Or a push for lab...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 50.0
# Neutral tweets percentage:% 50.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Do y’all see what...|       2.0|
# |RT @nursekelsey: ...|       4.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 100.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @nmorin2012: @...|       4.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 100.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @SEDLAW15: Quo...|       4.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 100.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @SEDLAW15: Quo...|       4.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 50.0
# Positive tweets percentage:% 25.0
# Neutral tweets percentage:% 25.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @V_actually: C...|       0.0|
# |Is this a ploy to...|       2.0|
# |Or a push for lab...|       0.0|
# |@TrumperSeaney @M...|       4.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 100.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |We got our asses ...|       2.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @bustedcoverag...|       0.0|
# |RT @Sam2323_43433...|       0.0|
# |        🚧🚧🚧🚧🚧🚧|       0.0|
# |All, Employees An...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |What do you get f...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@LisaMei62 Costco...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 100.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @PeterFotopoul...|       4.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 100.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |So much ass in th...|       4.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 100.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@takintime I love...|       4.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 100.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @Criss_Croix: ...|       2.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |I NEVER JOINED!  ...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |From Costco insta...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 100.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @fight4red: -I...|       2.0|
# |-I’m also seeing ...|       2.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 50.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 50.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @TrumperSeaney...|       2.0|
# |Ever since the ou...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 50.0
# Positive tweets percentage:% 25.0
# Neutral tweets percentage:% 25.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @V_actually: C...|       0.0|
# |Is this a ploy to...|       2.0|
# |Or a push for lab...|       0.0|
# |Costco limits mea...|       4.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 100.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @LonnieSaintPa...|       2.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 0.0
# Positive tweets percentage:% 100.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |RT @nursekelsey: ...|       4.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Costco Limits Mea...|       0.0|
# |Costco Limits Mea...|       0.0|
# +--------------------+----------+
#
# Edn
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |Costco Limits Mea...|       0.0|
# |Costco Limits Mea...|       0.0|
# |Costco Limits Mea...|       0.0|
# |Costco Limits Mea...|       0.0|
# |Costco Limits Mea...|       0.0|
# |Costco Limits Mea...|       0.0|
# |Costco Limits Mea...|       0.0|
# |Costco Limits Mea...|       0.0|
# |Costco Limits Mea...|       0.0|
# |Costco Limits Mea...|       0.0|
# |Costco Limits Mea...|       0.0|
# |Costco Limits Mea...|       0.0|
# |Costco Limits Mea...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 100.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 0.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |@banaifeldstein @...|       0.0|
# +--------------------+----------+
#
# Edn
# No data
# This Error: <class 'ValueError'>
# No data
# This Error: <class 'ValueError'>
# Negative tweets percentage:% 75.0
# Positive tweets percentage:% 0.0
# Neutral tweets percentage:% 25.0
# +--------------------+----------+
# |               tweet|prediction|
# +--------------------+----------+
# |In the "if the sh...|       0.0|
# |"Seth Rogen was s...|       0.0|
# |left wing people ...|       0.0|
# |Costco stayed mum...|       2.0|
# +--------------------+----------+
#
# Edn
